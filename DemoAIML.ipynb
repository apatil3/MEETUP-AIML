# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

#Preparing the data
ci_data = pd.read_csv('/Users/amipatil/Meetup-AIML/codeissues.csv')
ci_data
# X = ci_data.drop(columns=['Code Rating']) #input data sets
# y = ci_data['Code Rating'] #output data sets

#build a model using machine learing algorithm

# model = DecisionTreeClassifier()
# model.fit(X,y)
# prediction= model.predict([[2,6,8], [20,30,40]])
# prediction

#Calculate the Accuracy
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# model.fit(X_train, y_train)
# predictions = model.predict(X_test)

# score = accuracy_score(y_test, predictions)
# score
# Out:
#     Blocker Issues  Critical Issues  Code Rating
# 0                0                1  Rating is A
# 1                2                5  Rating is A
# 2                4                9  Rating is A
# 3                6               13  Rating is B
# 4                8               17  Rating is B
# 5               10               21  Rating is B
# 6               12               25  Rating is C
# 7               14               29  Rating is C
# 8               16               33  Rating is C
# 9               18               37  Rating is D
# 10              20               41  Rating is D
# 11              22               45  Rating is D
# 12              24               49  Rating is E
# 13              26               53  Rating is E
# 14              28               57  Rating is E
# 15              30               61  Rating is F
# 16              32               65  Rating is F
# 17              34               69  Rating is F
# 18              36               73  Rating is G
# 19              38               77  Rating is G
# 20              40               81  Rating is G
# 21              42               85  Rating is H
# 22              44               89  Rating is H
# 23              46               93  Rating is H
